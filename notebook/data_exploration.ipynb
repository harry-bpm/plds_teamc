# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import sklearn
import joblib
import io

# %%
pip install pyxlsb
# Out:
#   File "<ipython-input-19-f0cccef0c590>", line 1
#     pip3 install pyxlsb
#          ^
# SyntaxError: invalid syntax

# %%
tqdm.pandas()

# %% [markdown]
# Dataset 1

# %%
df1 = pd.read_excel('E:/projects/plds_teamc/data/ar-2010-2014-xlsb.xlsb',engine='pyxlsb')

# %%
df1.head()
# Out:
#   Patient Age at Treatment  \
# 0                  18 - 34
# 1                    35-37
# 2                  18 - 34
# 3                    38-39
# 4                    35-37
#
#    Date patient started trying to become pregnant OR date of last pregnancy  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Total Number of Previous cycles, Both IVF and DI  \
# 0                                                1
# 1                                                0
# 2                                                0
# 3                                                1
# 4                                                0
#
#   Total Number of Previous treatments, Both IVF and DI at clinic  \
# 0                                                  1
# ...

# %%
buffer = io.StringIO()
df1.info(buf=buffer)
s = buffer.getvalue()
with open("E:/projects/plds_teamc/data/dataset1_info.txt", "w",encoding="utf-8") as f:  # doctest: +SKIP
    f.write(s)

# %%
df1.nunique()
# Out:
# Patient Age at Treatment                                                     7
# Date patient started trying to become pregnant OR date of last pregnancy    21
# Total Number of Previous cycles, Both IVF and DI                             7
# Total Number of Previous treatments, Both IVF and DI at clinic               7
# Total Number of Previous IVF cycles                                          7
#                                                                             ..
# Heart Four Birth Outcome                                                     3
# Heart Four Birth Weight                                                      1
# Heart Four Sex                                                               1
# Heart Four Delivery Date                                                     2
# Heart Four Birth Congenital Abnormalities                                    0
# Length: 95, dtype: int64

# %% [markdown]
# Dataset 2

# %%
df2 = pd.read_excel('E:/projects/plds_teamc/data/ar-2015-2016-xlsb.xlsb',engine='pyxlsb')

# %%
df2.head()
# Out:
#   Patient Age at Treatment  \
# 0                    40-42
# 1                    45-50
# 2                    35-37
# 3                  18 - 34
# 4                  18 - 34
#
#    Date patient started trying to become pregnant OR date of last pregnancy  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Total Number of Previous cycles, Both IVF and DI  \
# 0                                                2
# 1                                                3
# 2                                                0
# 3                                                2
# 4                                                5
#
#   Total Number of Previous treatments, Both IVF and DI at clinic  \
# 0                                                  2
# ...

# %%
buffer = io.StringIO()
df2.info(buf=buffer)
s = buffer.getvalue()
with open("E:/projects/plds_teamc/data/dataset2_info.txt", "w",encoding="utf-8") as f:  # doctest: +SKIP
    f.write(s)

# %%
df2.nunique()
# Out:
# Patient Age at Treatment                                                     7
# Date patient started trying to become pregnant OR date of last pregnancy    18
# Total Number of Previous cycles, Both IVF and DI                             7
# Total Number of Previous treatments, Both IVF and DI at clinic               7
# Total Number of Previous IVF cycles                                          7
#                                                                             ..
# Heart Four Birth Outcome                                                     1
# Heart Four Birth Weight                                                      1
# Heart Four Sex                                                               1
# Heart Four Delivery Date                                                     1
# Heart Four Birth Congenital Abnormalities                                    0
# Length: 95, dtype: int64

# %% [markdown]
# Combine the datasets

# %%
frames = [df1, df2]
df_combined = pd.concat(frames)

# %%
df_combined.nunique()
# Out:
# Patient Age at Treatment                                                     7
# Date patient started trying to become pregnant OR date of last pregnancy    21
# Total Number of Previous cycles, Both IVF and DI                             7
# Total Number of Previous treatments, Both IVF and DI at clinic               7
# Total Number of Previous IVF cycles                                          7
#                                                                             ..
# Heart Four Birth Outcome                                                     3
# Heart Four Birth Weight                                                      2
# Heart Four Sex                                                               2
# Heart Four Delivery Date                                                     3
# Heart Four Birth Congenital Abnormalities                                    0
# Length: 95, dtype: int64
