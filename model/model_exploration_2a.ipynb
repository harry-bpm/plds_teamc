# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import sklearn
import joblib
import time
from string import punctuation

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score, f1_score, plot_roc_curve, make_scorer
from sklearn.calibration import CalibratedClassifierCV
from sklearn.utils.class_weight import compute_class_weight
import lightgbm as lgb
import nltk
from nltk.corpus import stopwords

tqdm.pandas()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier


from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt

# %%
def model_knn():
    """
    Function for initiating Logistic Regression Model
    """

    base_model = KNeighborsClassifier()

    
    return base_model

def model_dt():
    """
    Function for initiating Random Forest Model
    """
    
    base_model = DecisionTreeClassifier(random_state=42)
    
    return base_model

def model_mlp():
    """
    Function for initiating LightGBM Model
    """

    base_model = MLPClassifier(random_state=42, max_iter=300)
    
    return base_model

# %%
def select_model(train_log_dict):
    max_score = max(train_log_dict['model_score'])
    max_index = train_log_dict['model_score'].index(max_score)
    best_model = train_log_dict['model_fit'][max_index]
    name = train_log_dict['model_name'][max_index]

    return best_model, name

# %%
def fit(X_train, Y_train, model):

    model_fitted = model.fit(X_train, Y_train)
    return model_fitted

def validate(X_test, Y_test, model_fitted, ):

    auc_score = roc_auc_score(Y_test, model_fitted.predict_proba(X_test))


    return auc_score

# %%
def main(X_train, X_test, Y_train,  Y_test):
    

    # Initiate models
    knn = model_knn
    dt = model_dt
    mlp = model_mlp
    
    # Initiate logs
    train_log_dict = {'model': [knn, dt, mlp],
                      'model_name': [],
                      'model_score': []}


    # Try Each models
    for model in train_log_dict['model']:
        base_model = model()
        train_log_dict['model_name'].append(base_model.__class__.__name__)
        print(f'Fitting {base_model.__class__.__name__}')

        # Train
        fitted_model = fit(X_train, Y_train, base_model)

        # Validate
        score = validate(X_test, Y_test, fitted_model)
        train_log_dict['model_score'].append(score)

    best_model, best_report, best_threshold, name = select_model(train_log_dict)
    
    print(
        f"Model: {name}, Score: {best_report['f1-score']['macro avg']}")
    joblib.dump(best_model, 'E:\\projects\\plds_latihan\\pipeline\\mantab_model.pkl')
    joblib.dump(best_threshold, 'E:\\projects\\plds_latihan\\pipeline\\threshold.pkl')
    joblib.dump(train_log_dict, 'E:\\projects\\plds_latihan\\pipeline\\train_log.pkl')
    print(f'\n {best_report}')
    
    return best_model

# %%
def load_dataset():

    X_train = joblib.load("E:\\projects\\plds_teamc\\output\\X_train_3.pkl")
    X_test = joblib.load("E:\\projects\\plds_teamc\\output\\X_test_3.pkl")
    Y_train = joblib.load("E:\\projects\\plds_teamc\\output\\Y_train_3.pkl")
    Y_test = joblib.load("E:\\projects\\plds_teamc\\output\\Y_test_3.pkl")

    return X_train, X_test, Y_train,  Y_test

# %%
X_train, X_test, Y_train,  Y_test= load_dataset()

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (4.1.1)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorboard<2.10,>=2.9
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: setuptools in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (61.2.0)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Using cached tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Requirement already satisfied: packaging in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (3.19.1)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.1-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (3.6.0)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mhpra\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.33.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mhpra\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.4)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mhpra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\mhpra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mhpra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mhpra\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mhpra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mhpra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mhpra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mhpra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.9)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mhpra\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=142999fb40cb7d8ec140c7223b31152e1f32e50728be5a93b5049a99c4ac1fc1
#   Stored in directory: c:\users\mhpra\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: oauthlib, requests-oauthlib, tensorboard-plugin-wit, tensorboard-data-server, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
# Successfully installed absl-py-1.1.0 astunparse-1.6.3 flatbuffers-1.12 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.1 oauthlib-3.2.0 opt-einsum-3.3.0 requests-oauthlib-1.3.1 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20-py3-none-any.whl (46 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)

y_pred = dt.predict(X_test)

# %%
xx  = X_test.iloc[1000]
xx = xx.to_frame()
xx
y_pred = dt.predict(xx)
# Out:
# c:\Users\mhpra\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\projects\plds_teamc\notebook\model_exploration_2a.ipynb Cell 12 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/e%3A/projects/plds_teamc/notebook/model_exploration_2a.ipynb#ch0000034?line=1'>2</a> xx = xx.to_frame()
#       <a href='vscode-notebook-cell:/e%3A/projects/plds_teamc/notebook/model_exploration_2a.ipynb#ch0000034?line=2'>3</a> xx
# ----> <a href='vscode-notebook-cell:/e%3A/projects/plds_teamc/notebook/model_exploration_2a.ipynb#ch0000034?line=3'>4</a> y_pred = dt.predict(xx)
#
# File c:\Users\mhpra\anaconda3\lib\site-packages\sklearn\tree\_classes.py:467, in BaseDecisionTree.predict(self, X, check_input)
#     444 """Predict class or regression value for X.
#     445
#     446 For a classification model, the predicted class for each sample in X is
#    (...)
#     464     The predicted classes, or the predict values.
#     465 """
#     466 check_is_fitted(self)
# --> 467 X = self._validate_X_predict(X, check_input)
#     468 proba = self.tree_.predict(X)
#     469 n_samples = X.shape[0]
#
# File c:\Users\mhpra\anaconda3\lib\site-packages\sklearn\tree\_classes.py:433, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     431 """Validate the training data on predict (probabilities)."""
#     432 if check_input:
# --> 433     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     434     if issparse(X) and (
#     435         X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     436     ):
#     437         raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\mhpra\anaconda3\lib\site-packages\sklearn\base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File c:\Users\mhpra\anaconda3\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 1 features, but DecisionTreeClassifier is expecting 23 features as input.

# %%
y_pred
# Out:
# array([1., 0., 0., ..., 0., 0., 0.])

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, classification_report, average_precision_score
import xgboost as xgb
from xgboost import plot_importance, to_graphviz
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf
import graphviz
import pickle

# %%
def plot_roc(fpr, tpr, roc_auc):
    plt.plot(fpr, tpr)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve (area = %0.6f)' % roc_auc)
    plt.legend(loc="lower right")
    plt.show()


def plot_pr(recall,precision,average_precision):
    plt.step(recall, precision, color='b', alpha=0.2, where='post')
    plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall: {0:0.6f}'.format(average_precision))
    plt.show()


def plot_learning_curve(results,epochs):
    x_axis = range(0, epochs)
    fig, ax = plt.subplots()
    ax.plot(x_axis, results['validation_0']['logloss'], label='logloss-Train')
    ax.plot(x_axis, results['validation_1']['logloss'], label='logloss-Test')
    ax.plot(x_axis, results['validation_0']['auc'], label='auc-Train')
    ax.plot(x_axis, results['validation_1']['auc'], label='auc-Test')
    ax.legend()
    plt.ylabel('Log Loss/AUC')
    plt.title('XGBoost Log Loss and AUC evolution')
    plt.show()


def run_xgboost_and_calculate_auc(X_train, X_test, Y_train, Y_test ,
                                target='target',
                                drop='variable_to_find_and_exclude',
                                w=1,
                                plot_learning=False,
                                plot_variables=False,
                                plot_ROC_PR=False,
                                plot_confusion=False,
                                plot_graph_tree=False,
                                learning_rate=0.05,
                                max_depth=10,
                                esr=10,
                                CV=True,
                                title=True,
                                plot_all=False,
                                ensembler=False,
                                test_size=.2):
    '''
    Generic function to run xgboost to test the added changes and plot roc, learning and others and save the model.
    '''

    print(f'variables: {len(list(X_train))}, rows:{len(X_train)}, flags:{sum(list(Y_train))}')       
    clf = xgb.XGBClassifier(
        learning_rate=learning_rate,
        n_estimators=1000,
        max_depth=4,
        min_child_weight=4,
        gamma=0.6,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=5e-05,
        objective='binary:logistic',
        nthread=20,
        scale_pos_weight=w,
        seed=27)

    eval_set = [(X_train, Y_train), (X_test, Y_test)]

    if plot_all:
        plot_learning=True
        plot_variables=True
        plot_ROC_PR=True
        plot_confusion=True
        plot_graph_tree=False
        
    if CV:
        X = pd.concat([X_train,X_test])
        y = pd.concat([Y_train,Y_test])
        xgb_param = clf.get_xgb_params()
        xgtrain = xgb.DMatrix(X.values, y.values)
        cvresult = xgb.cv(xgb_param,
                            xgtrain,
                            num_boost_round=clf.get_params()['n_estimators'],
                            nfold=5,
                            metrics='auc',
                            early_stopping_rounds=esr)
        print(cvresult.tail(1))
        clf.set_params(n_estimators=cvresult.shape[0])

    clf.fit(X_train,
            Y_train,
            early_stopping_rounds=25,
            eval_metric=['auc','error','logloss'],
            eval_set=eval_set,
            verbose=False)

    Y_pred = clf.predict_proba(X_test)
    y_true = np.array(Y_test)
    y_scores = Y_pred[:, 1]

    fpr, tpr, _ = roc_curve(Y_test, y_scores)
    roc_auc = auc(fpr, tpr)
    average_precision = average_precision_score(Y_test, y_scores)
    precision, recall, _ = precision_recall_curve(Y_test, y_scores)

    if plot_ROC_PR:
        plot_roc(fpr, tpr, roc_auc)
        plot_pr(recall,precision,average_precision)
    else:
        print('Area under ROC: %0.6f' % roc_auc)

    if plot_graph_tree:
        xgb.plot_tree(clf, rankdir='LR')
        fig = plt.gcf()
        fig.set_size_inches(150, 100)

    if plot_learning:
        results = clf.evals_result()
        epochs = len(results['validation_0']['error'])

    if plot_variables:
        xgb.plot_importance(clf,max_num_features=20,importance_type='gain',xlabel='gain')

    if plot_confusion:
        print('\n', classification_report(y_true, y_scores.round()))

    if title:
        #timestr = time.strftime("%Y%m%d-%H%M%S")
        #path = 'E:\\projects\\plds_teamc\\model\\xgb\\0001.pkl'
        joblib.dump(clf,"E:\\projects\\plds_teamc\\model\\xgb\\0001.pkl")
        #clf.save_model("E:\\projects\\plds_teamc\\model\\xgb\\0001.model")
        #timestr = time.strftime("%Y%m%d-%H%M%S")
        #path = 'E:\\projects\\plds_teamc\\model\\xgb\\'
        #save_model(model=clf,path=path,title=str(title))
        
    if ensembler:
        return Y_test, y_scores

    print('-------------END EXECUTION-------------')

# %%
Y_test, y_scores = run_xgboost_and_calculate_auc(  X_train, X_test, Y_train, Y_test ,target='Survived',plot_all=True,ensembler=True)
# Out:
# variables: 23, rows:227262, flags:57455.0
#      train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 207        0.742907        0.00051       0.741541      0.001995
# c:\Users\mhpra\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\mhpra\anaconda3\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#                precision    recall  f1-score   support
#
#          0.0       0.75      0.99      0.85     72657
#          1.0       0.50      0.02      0.04     24742
#
#     accuracy                           0.75     97399
#    macro avg       0.62      0.51      0.45     97399
# weighted avg       0.69      0.75      0.65     97399

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Build VT-CNN2 Neural Net model using Keras primitives -- 
#  - Reshape [N,2,128] to [N,1,2,128] on input
#  - Pass through 2 2DConv/ReLu layers
#  - Pass through 2 Dense layers (ReLu and Softmax)
#  - Perform categorical cross entropy optimization
import tensorflow.keras.models as models
import tensorflow.keras.callbacks
from tensorflow.keras.layers import BatchNormalization, Dropout

from tensorflow.keras.layers import PReLU
from tensorflow.keras.layers import MaxPooling2D 
from tensorflow.keras.initializers import Constant

model = models.Sequential()
#model.add(Reshape([1]+in_shp, input_shape=in_shp))
model.add(Dense(16, name="dense1", kernel_initializer="he_normal"))
model.add(Dense(32, name="dense2", kernel_initializer="he_normal"))
model.add(Dropout(0.5))
model.add(Dense(64, name="dense3", kernel_initializer="he_normal"))
model.add(Dense(128, name="dense4", kernel_initializer="he_normal"))
model.add(BatchNormalization())
model.add(Dense(512, name="dense5", kernel_initializer="he_normal"))
model.add(Dropout(0.5))
model.add(Dense(128, name="dense6", kernel_initializer="he_normal"))
model.add(Dense(64, name="dense7", kernel_initializer="he_normal"))
model.add(Dropout(0.1))
model.add(Dense(32, name="dense8", kernel_initializer="he_normal"))
model.add(Dense(16, name="dense9", kernel_initializer="he_normal"))
model.add(Dense(1, name="dense10", kernel_initializer="he_normal", activation = 'sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

# %%
X_train = np.asarray(X_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
Y_train = np.asarray(Y_train).astype(np.float32)
Y_test = np.asarray(Y_test).astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\projects\plds_teamc\notebook\model_exploration_2a.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/projects/plds_teamc/notebook/model_exploration_2a.ipynb#ch0000011?line=0'>1</a> X_train = np.asarray(X_train).astype(np.float32)
#       <a href='vscode-notebook-cell:/e%3A/projects/plds_teamc/notebook/model_exploration_2a.ipynb#ch0000011?line=1'>2</a> X_test = np.asarray(X_test).astype(np.float32)
#       <a href='vscode-notebook-cell:/e%3A/projects/plds_teamc/notebook/model_exploration_2a.ipynb#ch0000011?line=2'>3</a> Y_train = np.asarray(Y_train).astype(np.float32)
#
# ValueError: could not convert string to float: '> 50'

# %%
nb_epoch = 100     # number of epochs to train on
batch_size = 1024 # training batch size
filepath = 'E:\\projects\\plds_teamc\\data\\HARRY.h5'

history = model.fit(X_train,
    Y_train,
    batch_size=batch_size,
    epochs=nb_epoch,
    verbose=2,
    validation_data=(X_test,Y_test),
    shuffle=True)


# convert the history.history dict to a pandas DataFrame:   
# #https://stackoverflow.com/questions/41061457/keras-how-to-save-the-training-history-attribute-of-the-history-object  
hist_df = pd.DataFrame(history.history) 
hist_csv_file = 'E:\\projects\\plds_teamc\\data\\history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)
# Out:
# Epoch 1/100
# 222/222 - 6s - loss: 0.7486 - accuracy: 0.7064 - val_loss: 0.5233 - val_accuracy: 0.7413 - 6s/epoch - 26ms/step
# Epoch 2/100
# 222/222 - 4s - loss: 0.5327 - accuracy: 0.7388 - val_loss: 0.5188 - val_accuracy: 0.7458 - 4s/epoch - 18ms/step
# Epoch 3/100
# 222/222 - 4s - loss: 0.5250 - accuracy: 0.7383 - val_loss: 0.5162 - val_accuracy: 0.7456 - 4s/epoch - 18ms/step
# Epoch 4/100
# 222/222 - 4s - loss: 0.5215 - accuracy: 0.7383 - val_loss: 0.5111 - val_accuracy: 0.7453 - 4s/epoch - 18ms/step
# Epoch 5/100
# 222/222 - 4s - loss: 0.5193 - accuracy: 0.7391 - val_loss: 0.5094 - val_accuracy: 0.7444 - 4s/epoch - 18ms/step
# Epoch 6/100
# 222/222 - 4s - loss: 0.5177 - accuracy: 0.7390 - val_loss: 0.5127 - val_accuracy: 0.7459 - 4s/epoch - 18ms/step
# Epoch 7/100
# 222/222 - 4s - loss: 0.5161 - accuracy: 0.7404 - val_loss: 0.5128 - val_accuracy: 0.7458 - 4s/epoch - 18ms/step
# Epoch 8/100
# 222/222 - 4s - loss: 0.5153 - accuracy: 0.7401 - val_loss: 0.5082 - val_accuracy: 0.7429 - 4s/epoch - 18ms/step
# Epoch 9/100
# 222/222 - 4s - loss: 0.5149 - accuracy: 0.7403 - val_loss: 0.5088 - val_accuracy: 0.7360 - 4s/epoch - 18ms/step
# Epoch 10/100
# 222/222 - 4s - loss: 0.5143 - accuracy: 0.7405 - val_loss: 0.5111 - val_accuracy: 0.7459 - 4s/epoch - 18ms/step
# Epoch 11/100
# 222/222 - 4s - loss: 0.5136 - accuracy: 0.7408 - val_loss: 0.5082 - val_accuracy: 0.7388 - 4s/epoch - 18ms/step
# Epoch 12/100
# 222/222 - 4s - loss: 0.5132 - accuracy: 0.7407 - val_loss: 0.5080 - val_accuracy: 0.7421 - 4s/epoch - 18ms/step
# Epoch 13/100
# 222/222 - 4s - loss: 0.5131 - accuracy: 0.7413 - val_loss: 0.5086 - val_accuracy: 0.7433 - 4s/epoch - 19ms/step
# Epoch 14/100
# 222/222 - 4s - loss: 0.5127 - accuracy: 0.7407 - val_loss: 0.5083 - val_accuracy: 0.7430 - 4s/epoch - 19ms/step
# Epoch 15/100
# 222/222 - 4s - loss: 0.5130 - accuracy: 0.7407 - val_loss: 0.5088 - val_accuracy: 0.7444 - 4s/epoch - 19ms/step
# Epoch 16/100
# 222/222 - 4s - loss: 0.5128 - accuracy: 0.7406 - val_loss: 0.5080 - val_accuracy: 0.7391 - 4s/epoch - 20ms/step
# Epoch 17/100
# 222/222 - 4s - loss: 0.5125 - accuracy: 0.7410 - val_loss: 0.5087 - val_accuracy: 0.7361 - 4s/epoch - 19ms/step
# Epoch 18/100
# 222/222 - 4s - loss: 0.5118 - accuracy: 0.7413 - val_loss: 0.5082 - val_accuracy: 0.7430 - 4s/epoch - 19ms/step
# Epoch 19/100
# 222/222 - 4s - loss: 0.5122 - accuracy: 0.7412 - val_loss: 0.5082 - val_accuracy: 0.7388 - 4s/epoch - 18ms/step
# Epoch 20/100
# 222/222 - 4s - loss: 0.5120 - accuracy: 0.7413 - val_loss: 0.5087 - val_accuracy: 0.7448 - 4s/epoch - 18ms/step
# Epoch 21/100
# 222/222 - 4s - loss: 0.5118 - accuracy: 0.7419 - val_loss: 0.5090 - val_accuracy: 0.7372 - 4s/epoch - 18ms/step
# Epoch 22/100
# 222/222 - 4s - loss: 0.5117 - accuracy: 0.7410 - val_loss: 0.5085 - val_accuracy: 0.7433 - 4s/epoch - 18ms/step
# Epoch 23/100
# 222/222 - 4s - loss: 0.5121 - accuracy: 0.7413 - val_loss: 0.5085 - val_accuracy: 0.7438 - 4s/epoch - 18ms/step
# Epoch 24/100
# 222/222 - 4s - loss: 0.5114 - accuracy: 0.7417 - val_loss: 0.5081 - val_accuracy: 0.7417 - 4s/epoch - 18ms/step
# Epoch 25/100
# 222/222 - 4s - loss: 0.5117 - accuracy: 0.7418 - val_loss: 0.5084 - val_accuracy: 0.7434 - 4s/epoch - 18ms/step
# Epoch 26/100
# 222/222 - 4s - loss: 0.5112 - accuracy: 0.7415 - val_loss: 0.5081 - val_accuracy: 0.7414 - 4s/epoch - 18ms/step
# Epoch 27/100
# 222/222 - 4s - loss: 0.5115 - accuracy: 0.7412 - val_loss: 0.5080 - val_accuracy: 0.7406 - 4s/epoch - 18ms/step
# Epoch 28/100
# 222/222 - 4s - loss: 0.5116 - accuracy: 0.7414 - val_loss: 0.5080 - val_accuracy: 0.7423 - 4s/epoch - 18ms/step
# Epoch 29/100
# 222/222 - 4s - loss: 0.5118 - accuracy: 0.7417 - val_loss: 0.5081 - val_accuracy: 0.7411 - 4s/epoch - 18ms/step
# Epoch 30/100
# 222/222 - 4s - loss: 0.5114 - accuracy: 0.7412 - val_loss: 0.5082 - val_accuracy: 0.7433 - 4s/epoch - 19ms/step
# Epoch 31/100
# 222/222 - 4s - loss: 0.5113 - accuracy: 0.7415 - val_loss: 0.5087 - val_accuracy: 0.7442 - 4s/epoch - 18ms/step
# Epoch 32/100
# 222/222 - 4s - loss: 0.5108 - accuracy: 0.7420 - val_loss: 0.5080 - val_accuracy: 0.7426 - 4s/epoch - 18ms/step
# Epoch 33/100
# 222/222 - 4s - loss: 0.5112 - accuracy: 0.7414 - val_loss: 0.5101 - val_accuracy: 0.7329 - 4s/epoch - 18ms/step
# Epoch 34/100
# 222/222 - 4s - loss: 0.5111 - accuracy: 0.7422 - val_loss: 0.5080 - val_accuracy: 0.7390 - 4s/epoch - 18ms/step
# Epoch 35/100
# 222/222 - 4s - loss: 0.5112 - accuracy: 0.7414 - val_loss: 0.5098 - val_accuracy: 0.7456 - 4s/epoch - 18ms/step
# Epoch 36/100
# 222/222 - 4s - loss: 0.5111 - accuracy: 0.7419 - val_loss: 0.5087 - val_accuracy: 0.7445 - 4s/epoch - 18ms/step
# Epoch 37/100
# 222/222 - 4s - loss: 0.5110 - accuracy: 0.7419 - val_loss: 0.5108 - val_accuracy: 0.7458 - 4s/epoch - 18ms/step
# Epoch 38/100
# 222/222 - 4s - loss: 0.5112 - accuracy: 0.7412 - val_loss: 0.5080 - val_accuracy: 0.7414 - 4s/epoch - 19ms/step
# Epoch 39/100
# 222/222 - 4s - loss: 0.5109 - accuracy: 0.7414 - val_loss: 0.5079 - val_accuracy: 0.7423 - 4s/epoch - 18ms/step
# Epoch 40/100
# 222/222 - 4s - loss: 0.5110 - accuracy: 0.7421 - val_loss: 0.5111 - val_accuracy: 0.7454 - 4s/epoch - 18ms/step
# Epoch 41/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7417 - val_loss: 0.5080 - val_accuracy: 0.7396 - 4s/epoch - 18ms/step
# Epoch 42/100
# 222/222 - 4s - loss: 0.5108 - accuracy: 0.7420 - val_loss: 0.5084 - val_accuracy: 0.7385 - 4s/epoch - 18ms/step
# Epoch 43/100
# 222/222 - 4s - loss: 0.5109 - accuracy: 0.7418 - val_loss: 0.5083 - val_accuracy: 0.7381 - 4s/epoch - 19ms/step
# Epoch 44/100
# 222/222 - 4s - loss: 0.5109 - accuracy: 0.7421 - val_loss: 0.5104 - val_accuracy: 0.7321 - 4s/epoch - 18ms/step
# Epoch 45/100
# 222/222 - 4s - loss: 0.5113 - accuracy: 0.7415 - val_loss: 0.5120 - val_accuracy: 0.7458 - 4s/epoch - 18ms/step
# Epoch 46/100
# 222/222 - 4s - loss: 0.5109 - accuracy: 0.7418 - val_loss: 0.5099 - val_accuracy: 0.7455 - 4s/epoch - 19ms/step
# Epoch 47/100
# 222/222 - 4s - loss: 0.5105 - accuracy: 0.7415 - val_loss: 0.5099 - val_accuracy: 0.7456 - 4s/epoch - 18ms/step
# Epoch 48/100
# 222/222 - 4s - loss: 0.5110 - accuracy: 0.7416 - val_loss: 0.5079 - val_accuracy: 0.7421 - 4s/epoch - 18ms/step
# Epoch 49/100
# 222/222 - 4s - loss: 0.5108 - accuracy: 0.7421 - val_loss: 0.5089 - val_accuracy: 0.7358 - 4s/epoch - 18ms/step
# Epoch 50/100
# 222/222 - 4s - loss: 0.5108 - accuracy: 0.7423 - val_loss: 0.5079 - val_accuracy: 0.7423 - 4s/epoch - 18ms/step
# Epoch 51/100
# 222/222 - 4s - loss: 0.5111 - accuracy: 0.7419 - val_loss: 0.5079 - val_accuracy: 0.7416 - 4s/epoch - 18ms/step
# Epoch 52/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7414 - val_loss: 0.5080 - val_accuracy: 0.7409 - 4s/epoch - 18ms/step
# Epoch 53/100
# 222/222 - 4s - loss: 0.5105 - accuracy: 0.7421 - val_loss: 0.5086 - val_accuracy: 0.7437 - 4s/epoch - 18ms/step
# Epoch 54/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7417 - val_loss: 0.5080 - val_accuracy: 0.7422 - 4s/epoch - 18ms/step
# Epoch 55/100
# 222/222 - 4s - loss: 0.5108 - accuracy: 0.7423 - val_loss: 0.5127 - val_accuracy: 0.7303 - 4s/epoch - 18ms/step
# Epoch 56/100
# 222/222 - 4s - loss: 0.5108 - accuracy: 0.7424 - val_loss: 0.5086 - val_accuracy: 0.7442 - 4s/epoch - 18ms/step
# Epoch 57/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7423 - val_loss: 0.5081 - val_accuracy: 0.7385 - 4s/epoch - 18ms/step
# Epoch 58/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7418 - val_loss: 0.5085 - val_accuracy: 0.7398 - 4s/epoch - 18ms/step
# Epoch 59/100
# 222/222 - 4s - loss: 0.5108 - accuracy: 0.7415 - val_loss: 0.5088 - val_accuracy: 0.7450 - 4s/epoch - 18ms/step
# Epoch 60/100
# 222/222 - 4s - loss: 0.5110 - accuracy: 0.7417 - val_loss: 0.5089 - val_accuracy: 0.7450 - 4s/epoch - 18ms/step
# Epoch 61/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7416 - val_loss: 0.5086 - val_accuracy: 0.7445 - 4s/epoch - 19ms/step
# Epoch 62/100
# 222/222 - 4s - loss: 0.5106 - accuracy: 0.7422 - val_loss: 0.5079 - val_accuracy: 0.7404 - 4s/epoch - 18ms/step
# Epoch 63/100
# 222/222 - 4s - loss: 0.5105 - accuracy: 0.7418 - val_loss: 0.5080 - val_accuracy: 0.7400 - 4s/epoch - 19ms/step
# Epoch 64/100
# 222/222 - 4s - loss: 0.5106 - accuracy: 0.7421 - val_loss: 0.5089 - val_accuracy: 0.7450 - 4s/epoch - 19ms/step
# Epoch 65/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7419 - val_loss: 0.5079 - val_accuracy: 0.7411 - 4s/epoch - 19ms/step
# Epoch 66/100
# 222/222 - 4s - loss: 0.5105 - accuracy: 0.7422 - val_loss: 0.5092 - val_accuracy: 0.7453 - 4s/epoch - 19ms/step
# Epoch 67/100
# 222/222 - 4s - loss: 0.5102 - accuracy: 0.7421 - val_loss: 0.5102 - val_accuracy: 0.7388 - 4s/epoch - 19ms/step
# Epoch 68/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7419 - val_loss: 0.5079 - val_accuracy: 0.7424 - 4s/epoch - 19ms/step
# Epoch 69/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7425 - val_loss: 0.5079 - val_accuracy: 0.7415 - 4s/epoch - 18ms/step
# Epoch 70/100
# 222/222 - 4s - loss: 0.5105 - accuracy: 0.7421 - val_loss: 0.5081 - val_accuracy: 0.7433 - 4s/epoch - 18ms/step
# Epoch 71/100
# 222/222 - 4s - loss: 0.5106 - accuracy: 0.7420 - val_loss: 0.5091 - val_accuracy: 0.7450 - 4s/epoch - 19ms/step
# Epoch 72/100
# 222/222 - 4s - loss: 0.5105 - accuracy: 0.7420 - val_loss: 0.5095 - val_accuracy: 0.7448 - 4s/epoch - 18ms/step
# Epoch 73/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7422 - val_loss: 0.5096 - val_accuracy: 0.7456 - 4s/epoch - 18ms/step
# Epoch 74/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7427 - val_loss: 0.5103 - val_accuracy: 0.7352 - 4s/epoch - 18ms/step
# Epoch 75/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7425 - val_loss: 0.5082 - val_accuracy: 0.7421 - 4s/epoch - 19ms/step
# Epoch 76/100
# 222/222 - 4s - loss: 0.5102 - accuracy: 0.7422 - val_loss: 0.5087 - val_accuracy: 0.7438 - 4s/epoch - 19ms/step
# Epoch 77/100
# 222/222 - 4s - loss: 0.5106 - accuracy: 0.7423 - val_loss: 0.5080 - val_accuracy: 0.7428 - 4s/epoch - 18ms/step
# Epoch 78/100
# 222/222 - 4s - loss: 0.5106 - accuracy: 0.7421 - val_loss: 0.5088 - val_accuracy: 0.7441 - 4s/epoch - 18ms/step
# Epoch 79/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7420 - val_loss: 0.5089 - val_accuracy: 0.7444 - 4s/epoch - 18ms/step
# Epoch 80/100
# 222/222 - 4s - loss: 0.5106 - accuracy: 0.7418 - val_loss: 0.5087 - val_accuracy: 0.7450 - 4s/epoch - 18ms/step
# Epoch 81/100
# 222/222 - 4s - loss: 0.5106 - accuracy: 0.7422 - val_loss: 0.5086 - val_accuracy: 0.7364 - 4s/epoch - 19ms/step
# Epoch 82/100
# 222/222 - 4s - loss: 0.5103 - accuracy: 0.7426 - val_loss: 0.5080 - val_accuracy: 0.7426 - 4s/epoch - 18ms/step
# Epoch 83/100
# 222/222 - 4s - loss: 0.5102 - accuracy: 0.7423 - val_loss: 0.5085 - val_accuracy: 0.7433 - 4s/epoch - 18ms/step
# Epoch 84/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7421 - val_loss: 0.5080 - val_accuracy: 0.7427 - 4s/epoch - 18ms/step
# Epoch 85/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7424 - val_loss: 0.5079 - val_accuracy: 0.7407 - 4s/epoch - 18ms/step
# Epoch 86/100
# 222/222 - 4s - loss: 0.5103 - accuracy: 0.7423 - val_loss: 0.5090 - val_accuracy: 0.7384 - 4s/epoch - 19ms/step
# Epoch 87/100
# 222/222 - 4s - loss: 0.5107 - accuracy: 0.7417 - val_loss: 0.5086 - val_accuracy: 0.7408 - 4s/epoch - 19ms/step
# Epoch 88/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7420 - val_loss: 0.5081 - val_accuracy: 0.7432 - 4s/epoch - 19ms/step
# Epoch 89/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7423 - val_loss: 0.5079 - val_accuracy: 0.7396 - 4s/epoch - 19ms/step
# Epoch 90/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7427 - val_loss: 0.5082 - val_accuracy: 0.7428 - 4s/epoch - 19ms/step
# Epoch 91/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7419 - val_loss: 0.5086 - val_accuracy: 0.7400 - 4s/epoch - 19ms/step
# Epoch 92/100
# 222/222 - 4s - loss: 0.5102 - accuracy: 0.7425 - val_loss: 0.5080 - val_accuracy: 0.7404 - 4s/epoch - 18ms/step
# Epoch 93/100
# 222/222 - 4s - loss: 0.5103 - accuracy: 0.7423 - val_loss: 0.5078 - val_accuracy: 0.7418 - 4s/epoch - 19ms/step
# Epoch 94/100
# 222/222 - 4s - loss: 0.5103 - accuracy: 0.7423 - val_loss: 0.5080 - val_accuracy: 0.7430 - 4s/epoch - 18ms/step
# Epoch 95/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7422 - val_loss: 0.5083 - val_accuracy: 0.7430 - 4s/epoch - 18ms/step
# Epoch 96/100
# 222/222 - 4s - loss: 0.5102 - accuracy: 0.7419 - val_loss: 0.5093 - val_accuracy: 0.7359 - 4s/epoch - 19ms/step
# Epoch 97/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7425 - val_loss: 0.5092 - val_accuracy: 0.7450 - 4s/epoch - 19ms/step
# Epoch 98/100
# 222/222 - 4s - loss: 0.5102 - accuracy: 0.7425 - val_loss: 0.5081 - val_accuracy: 0.7429 - 4s/epoch - 19ms/step
# Epoch 99/100
# 222/222 - 4s - loss: 0.5104 - accuracy: 0.7420 - val_loss: 0.5084 - val_accuracy: 0.7437 - 4s/epoch - 19ms/step
# Epoch 100/100
# 222/222 - 4s - loss: 0.5103 - accuracy: 0.7420 - val_loss: 0.5081 - val_accuracy: 0.7424 - 4s/epoch - 19ms/step

# %%
acc_threshold = hist_df["accuracy"].mean()
joblib.dump(acc_threshold, 'E:\\projects\\plds_teamc\\data\\acc_threshold.pkl')
# Out:
# ['E:\\projects\\plds_teamc\\data\\acc_threshold.pkl']

# %%
base_model = KNeighborsClassifier(n_neighbors=50)
#base_model = DecisionTreeClassifier(random_state=42)

#base_model = MLPClassifier(hidden_layer_sizes=(100,300,150), random_state=42, max_iter=300)


model_fitted = base_model.fit(X_train, Y_train)

#auc_score = roc_auc_score(Y_test, model_fitted.predict(X_test))
auc_score = roc_auc_score(Y_test, model_fitted.predict(X_test))

# %%
X_train, X_test, Y_train,  Y_test= load_dataset()
text=X_train.iloc[1000]
text.to_csv('E:\projects\plds_teamc\data\sample2.csv')  
text
# Out:
# Patient Age at Treatment                                          0.0
# Total Number of Previous treatments, Both IVF and DI at clinic    0.0
# Total Number of Previous IVF cycles                               0.0
# Total number of IVF pregnancies                                   0.0
# Type of Infertility - Female Primary                              0.0
# Type of Infertility - Female Secondary                            0.0
# Type of Infertility - Male Primary                                0.0
# Type of Infertility - Male Secondary                              0.0
# Type of Infertility -Couple Primary                               0.0
# Type of Infertility -Couple Secondary                             0.0
# Cause  of Infertility - Tubal disease                             0.0
# Cause of Infertility - Ovulatory Disorder                         0.0
# Cause of Infertility - Male Factor                                1.0
# Cause of Infertility - Patient Unexplained                        0.0
# Cause of Infertility - Endometriosis                              0.0
# Cause of Infertility - Cervical factors                           0.0
# Cause of Infertility - Female Factors                             0.0
# Cause of Infertility - Partner Sperm Concentration                0.0
# Cause of Infertility -  Partner Sperm Morphology                  0.0
# Causes of Infertility - Partner Sperm Motility                    0.0
# Cause of Infertility -  Partner Sperm Immunological factors       0.0
# Embryos Transfered                                                2.0
# Total Embryos Created                                             3.0
# Name: 166945, dtype: float64

# %%
#joblib.dump(model, 'E:\\projects\\plds_teamc\\data\\mantab_model.pkl')
model.save('E:\\projects\\plds_teamc\\data\\')
# Out:
# INFO:tensorflow:Assets written to: E:\projects\plds_teamc\data\assets

# %%
from sklearn.datasets import load_svmlight_file
def main_predict(text, model, threshold):
    text = text[[text.columns[1]]]
    text = np.asarray(text).astype(np.float32).T
    text = text.reshape(-1, 23)
    code2rel = {0: 'Tidak berhasil', 1: 'Berhasil'}
    
    proba = model.predict(text)
    predict = 1 if proba > threshold else 0
    #print(f"{code2rel[predict]}, dengan akurasi {proba}")

    #return code2rel[predict], proba
    return code2rel[predict], proba

# %%
#model = models.load_model('E:\\projects\\plds_teamc\\model\\xgb\\0001.model')
#model = xgb.Booster({'nthread': 4})  # init model
#model.load_model('E:\\projects\\plds_teamc\\model\\xgb\\0001.model')
from tensorflow import keras
model = keras.models.load_model('E:\\projects\\plds_teamc\\data\\')
#model = joblib.load('E:\\projects\\plds_teamc\\model\\xgb\\0001.pkl')
#threshold = joblib.load('E:\\projects\\plds_teamc\\data\\acc_threshold.pkl')

# %%
text = pd.read_csv("E:\projects\plds_teamc\data\sample2 - Copy.csv", index_col = False)
#text=X_train.iloc[100].T
#text =  X_test
#text = X_test.iloc[[1389]].T
##text = xgb.DMatrix(text)
#text = pd.read_csv('E:\projects\plds_teamc\data\sample2 - Copy.csv').T
#text.shape
#text = np.asarray(text).astype(np.float32)
#text.shape
text
# Out:
#                                            Unnamed: 0  166945
# 0                            Patient Age at Treatment       2
# 1   Total Number of Previous treatments, Both IVF ...       1
# 2                 Total Number of Previous IVF cycles       1
# 3                     Total number of IVF pregnancies       2
# 4                Type of Infertility - Female Primary       0
# 5              Type of Infertility - Female Secondary       0
# 6                  Type of Infertility - Male Primary       0
# 7                Type of Infertility - Male Secondary       0
# 8                 Type of Infertility -Couple Primary       0
# 9               Type of Infertility -Couple Secondary       0
# 10              Cause  of Infertility - Tubal disease       0
# 11          Cause of Infertility - Ovulatory Disorder       0
# 12                 Cause of Infertility - Male Factor       0
# 13         Cause of Infertility - Patient Unexplained       0
# 14               Cause of Infertility - Endometriosis       0
# 15            Cause of Infertility - Cervical factors       0
# 16              Cause of Infertility - Female Factors       0
# 17  Cause of Infertility - Partner Sperm Concentra...       0
# 18   Cause of Infertility -  Partner Sperm Morphology       0
# 19     Causes of Infertility - Partner Sperm Motility       0
# 20  Cause of Infertility -  Partner Sperm Immunolo...       0
# 21                                 Embryos Transfered       2
# 22                              Total Embryos Created       4

# %%
gg = Y_test.iloc[[1389]]
gg
# Out:
# 174929    1.0
# Name: Live Birth Occurrence, dtype: float64

# %%
threshold = 0.741541
proba = main_predict(text, model, threshold)
proba
# Out:
# 1/1 [==============================] - 0s 20ms/step
# ('Tidak berhasil', array([[0.353939]], dtype=float32))
